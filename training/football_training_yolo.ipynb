# %%
from roboflow import Roboflow
rf = Roboflow(api_key="ZEWNuiKo3Av5o75MWGmQ")
project = rf.workspace("jan-0y4l3").project("football-players-detection-3zvbc-uibl7")
version = project.version(1)
dataset = version.download("yolov11")

# %%
dataset.location
# Out:
# '/Users/home/Desktop/football/training/football-players-detection-1'

# %% [markdown]
# # Training

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="ZEWNuiKo3Av5o75MWGmQ")
workspace = rf.workspace("jan-0y4l3")
project = workspace.project("football-ball-detection-rejhg-uxa03")
version = project.version(1)

# Deploy your custom trained weights
version.deploy(
    model_type="yolov11",
    model_path="/Users/home/Desktop/football/models/weights",
    filename="best.pt"
)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# View the status of your deployment at: https://app.roboflow.com/jan-0y4l3/football-ball-detection-rejhg-uxa03/1
# Share your model with the world at: https://universe.roboflow.com/jan-0y4l3/football-ball-detection-rejhg-uxa03/model/1
